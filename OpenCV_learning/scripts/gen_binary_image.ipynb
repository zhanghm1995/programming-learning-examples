# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %% [markdown]
# ## Find the white region

# %%
img_path = "/home/haimingzhang/Research/Programming/cv-fighter/facial_preprocessed/debug/000000.jpg"

src_img = cv2.imread(img_path)

gray = cv2.cvtColor(src_img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray))

ret,gray = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)

display(Image.fromarray(gray))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA3154F0630>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA3154F05C0>

# %%
import numpy as np

below_face_mask = np.load("/home/haimingzhang/Research/Programming/cv-fighter/face_fighter/3DMM/big_mouth_mask.npy")

print(below_face_mask.shape, below_face_mask.dtype)
# Out:
# (35709,) bool

# %% [markdown]
# ## Stat the masked image

# %%
img_path = ""
