# %%
import math

# %% [markdown]
# ## Ceil and round floating data

# %%
data = 3.4
# data = 3.5

output = math.ceil(data)
print(output, type(output))

output = round(data)
print(output, type(output))
# Out:
# 4 <class 'int'>
# 3 <class 'int'>
