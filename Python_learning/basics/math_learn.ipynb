# %%
import math

# %% [markdown]
# ## Ceil and round floating data

# %%
data = 3.4
# data = 3.5

output = math.ceil(data)
print(output, type(output))

output = round(data)
print(output, type(output))
# Out:
# 4 <class 'int'>
# 3 <class 'int'>

# %%
import math
from math import isqrt

n = 924
output = isqrt(n)
print(output, type(output))

output = math.floor(math.sqrt(n))
print(output, type(output))
# Out:
# 30 <class 'int'>
# 30 <class 'int'>

# %%
aa = 10.0
aa /= 2 - 1
print(aa)
# Out:
# 10.0

# %%
data = [19.52, 11.26, 26.11, 29.78, 10.47, 13.83, 12.58, 8.67, 12.74, 21.57, 39.63, 23.28, 24.46, 22.99, 9.59, 19.12]
# compute the mean
mean = sum(data) / len(data)
print("Mean:", mean)
# Out:
# Mean: 19.099999999999998

# %%
mTP = 0.562 + 0.265 + 0.321 + 0.243 + 0.195
mAP = 0.501
NDS = (5 * mAP + 5 - mTP) / 10
print(NDS)

mTP = 0.532 + 0.251 + 0.318 + 0.241 + 0.185
mAP = 0.509
NDS = (5 * mAP + 5 - mTP) / 10
print(NDS)

mTP = 0.564 + 0.263 + 0.362 + 0.232 + 0.182
mAP = 0.452
NDS = (5 * mAP + 5 - mTP) / 10
print(NDS)
# Out:
# 0.5919
# 0.6018
# 0.5657

# %%
data = [19.52, 11.26, 26.11, 29.78, 10.47, 13.83, 12.58, 8.67, 12.74, 21.57, 39.63, 23.28, 24.46, 22.99, 9.59, 19.12]
# compute the mean
mean = sum(data) / len(data)
print("Mean:", mean)

data = [19.98, 11.86, 28.21, 30.68, 10.87, 15.03, 14.28, 9.57, 14.74, 22.98, 39.82, 23.88, 25.46, 23.09, 14.56, 21.31]
# compute the mean
mean = sum(data) / len(data)
print("Mean:", mean)
# Out:
# Mean: 19.099999999999998
# Mean: 20.394999999999996
